-- %%
-- Test DB connection
SELECT
@@SERVERNAME AS ServerName,
DB_NAME() AS DatabaseName;
-- Out:
-- (1 row affected)
--
-- ServerName      | DatabaseName
-- ----------------+-------------
-- EC2AMAZ-8NC6CBJ | rw1026852
-- (1 row)
--
-- Total execution time: 00:00:00.034

-- %% [markdown]
-- # Welcome to your first Jupyter Notebook
--
-- Jupyter notebooks allow for programmers to create markdown documents that include executable code. At first glance, this may seem frivilous, however it can be extremely useful for documentation, tutorials, shared scripts, and education. Thanks to the powerful markdown tools available, we can highlight <mark>important information</mark>, or user **_<u>other formatting</u>_** to get our point across.
--
-- Notebooks are made up of two types of content that are divided into cells. We have markdown (MD) cells like this one, and we have code cells. The coolest part is that if you have the Jupyter Notebooke file, or .ipynb, then you can make your own changes to both code and markdown cells. There are going to be bits of SQL code in this notebook that you have not yet been exposed to. That is okay! This is just for a demonstration and you do not have to know this code right away. We will have a seperate notebook where you practice scripts like these.

-- %% [markdown]
-- This is a new cell! Try editing it yourself by clicking on the cell, and then clicking the edit (pencil) button. Now, change the highlighted word to be your name. <mark>R. Tanner West</mark>
--
-- You can also double click a cell to quickly edit.

-- %% [markdown]
-- See, that wasn't so hard! Next we are going to check out a couple of code cells. The below code cells will connect to your database if you have followed the setup steps for ADS in Canvas. Before you can run SQL code cells, you will need to attach your database to this notebook. To do so:
--
-- 1. In the tool bar at the top of the notebook, open the "Attach to" dropdown and click "Change Connection".
-- 2. In the pane that appears, you should see the database connection you setup previously under "Recents"
--     1. If so, click on the server name, re-enter your password, and click "Connect"
--     2. If there is nothing in your recents, you will have to reference the connection info in Canvas to connect to the database
--
-- Once you are connected, try running the below code cell to create a table in your database. You run code cells by hovering on the cell, and clicking the play button that appears

-- %%
CREATE TABLE Wild_Animals ("Species" Varchar(30))
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.036

-- %% [markdown]
-- If all went well, you should see a confirmation that your commands completed succesfully. If not, then you may need to check your connection settings.

-- %% [markdown]
-- Let's practice editing a code cell. The process is the same as editing a markdown cell. Try editing the below code cell to replace "AnimalName" with the name of an animal. You must leave the single quotes. Once you have editted the cell, run it.

-- %%
INSERT INTO Wild_Animals (Species) VALUES ('Dog')
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.034

-- %% [markdown]
-- If you were succesful, you should see a message that 1 row was affected. Next, let's demonstrate how to view the results of a SELECT query in a notebook. Run the code cell below.

-- %%
SELECT * FROM Wild_Animals
-- Out:
-- (1 row affected)
--
-- Species
-- -------
-- Dog
-- (1 row)
--
-- Total execution time: 00:00:00.041

-- %% [markdown]
-- The above code cell should have produced a preview of the result in the form of a table. Our table only had one record, but the notebook is capable of displaying larger datasets. Notice the icons above the table? You can hover on these to see what each of them do. They allow you to easily share you query results on the fly via handy formats like csv.

-- %% [markdown]
-- Finally, let's clean up our database. Since the table we created was just for demonstration, we can go ahead and delete it using the query below:

-- %%
DROP TABLE Wild_Animals
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.035

-- %% [markdown]
-- Now that our table has been deleted (Dropped) we have concluded our exercise! One more cool thing before you turn this in... At the top of the notebook, there is a button that says "Run All". Before you click that button, scroll back up to the cell where we added data to our table (starts with INSERT INTO) and change that animal name to something different. Once that is done, click "Run all".

-- %% [markdown]
-- If you look at the results of your select query, you should notice that the result shows the new animal instead of the old one. The "Run all" button allows us to run through all of the code cells in the notebook at once!

-- %% [markdown]
-- Excellent work on this exercise! Be sure to go to "File" and save your changes. Once your notebook is saved you can submit it to Canvas for grading!
